# %%
# !sudo apt update && sudo apt install libglu1-mesa-dev -y
# !pip install landingai
# Out:
# Hit:1 http://security.ubuntu.com/ubuntu focal-security InRelease
# Hit:2 http://archive.ubuntu.com/ubuntu focal InRelease
# Hit:3 https://packages.microsoft.com/repos/microsoft-ubuntu-focal-prod focal InRelease
# Hit:4 https://dl.yarnpkg.com/debian stable InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu focal-updates InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu focal-backports InRelease
# Hit:7 https://repo.anaconda.com/pkgs/misc/debrepo/conda stable InRelease
# Hit:8 https://packagecloud.io/github/git-lfs/ubuntu focal InRelease3m
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# 35 packages can be upgraded. Run 'apt list --upgradable' to see them.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   libdrm-amdgpu1 libdrm-intel1 libdrm-nouveau2 libdrm-radeon1 libegl-dev
# ...

# %%
from landingai.pipeline.image_source import Frame, Webcam
from landingai.predict import Predictor

# %%
predictor = Predictor(
    api_key="land_sk_GufHzNiRuA26RGUtbV7eQbumBgCJxQkdR1NHUXwfk0xu7dugvT",
    endpoint_id="5fcfd012-8f76-49c7-a563-193cec91398f",
)

for image_index in range(1, 8):
  image_file = f"test{image_index}.jpg"
  frame = Frame.from_image(image_file)
  frame.run_predict(predictor)
  frame.overlay_predictions()
  frame.show_image(include_predictions="stone" in frame.predictions)
  print(f"O arquivo {image_file} contém ~{len(frame.predictions)} pedras")
# Out:
# <PIL.Image.Image image mode=RGB size=391x320>
# O arquivo test1.jpg contém ~2 pedras
# <PIL.Image.Image image mode=RGB size=391x320>
# O arquivo test2.jpg contém ~1 pedras
# No predictions to overlay, returning original image
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=391x320>
# O arquivo test3.jpg contém ~0 pedras
# <PIL.Image.Image image mode=RGB size=391x320>
# O arquivo test4.jpg contém ~2 pedras
# <PIL.Image.Image image mode=RGB size=391x320>
# O arquivo test5.jpg contém ~2 pedras
# <PIL.Image.Image image mode=RGB size=391x320>
# O arquivo test6.jpg contém ~1 pedras
# <PIL.Image.Image image mode=RGB size=391x320>
# O arquivo test7.jpg contém ~3 pedras
